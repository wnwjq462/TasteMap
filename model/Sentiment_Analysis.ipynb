# %%
import re
import os
import sys
import json

from pykospacing import Spacing
from konlpy.tag import Kkma
from konlpy.tag import Okt
import soynlp

kkma = Kkma()
okt = Okt()
spacing = Spacing()

# %%
import pandas as pd

# %%
# !pip install soynlp
# Out:
# Collecting soynlp
#   Downloading soynlp-0.0.493-py3-none-any.whl (416 kB)
#      |████████████████████████████████| 416 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.1.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from soynlp) (1.5.2)
# Requirement already satisfied: numpy>=1.12.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from soynlp) (1.19.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from soynlp) (0.23.2)
# Requirement already satisfied: psutil>=5.0.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from soynlp) (5.7.2)
# Requirement already satisfied: joblib>=0.11 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->soynlp) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->soynlp) (2.1.0)
# Installing collected packages: soynlp
# Successfully installed soynlp-0.0.493

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /private/var/folders/9w/lj4thvdd3wxfjk4zp5f3cydm0000gn/T/pip-req-build-r2sje8dp
# Requirement already satisfied: tensorflow==2.5.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from pykospacing==0.5) (2.5.0)
# Requirement already satisfied: h5py==3.1.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from pykospacing==0.5) (3.1.0)
# Collecting argparse>=1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: grpcio~=1.34.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.34.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (3.17.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: gast==0.4.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (0.4.0)
# Requirement already satisfied: tensorboard~=2.5 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.1.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (2.5.0.dev2021032900)
# Requirement already satisfied: six~=1.15.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (1.19.2)
# Requirement already satisfied: google-pasta~=0.2 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (0.35.1)
# Requirement already satisfied: absl-py~=0.10 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.5.0->pykospacing==0.5) (0.12.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (1.30.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (50.3.1.post20201107)
# Requirement already satisfied: markdown>=2.6.8 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (3.3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (1.25.11)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (4.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/pdh/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0->pykospacing==0.5) (0.4.8)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py) ... done
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255642 sha256=0812c07d53f2787f2ba6df91235c693c52381f537bfbc49f69c7d9f237c57c28
#   Stored in directory: /private/var/folders/9w/lj4thvdd3wxfjk4zp5f3cydm0000gn/T/pip-ephem-wheel-cache-7omnwr7h/wheels/79/a0/33/16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: argparse, pykospacing
# Successfully installed argparse-1.4.0 pykospacing-0.5

# %%
df = pd.read_csv("review_naver_sinchon.csv")

# %%
tf = pd.read_csv("reviews_instagram_0-100.csv")

# %%
tf.head(50)
# Out:
#     dining_id total_name                                             review  \
# 0           3    콘하스 연희점  오랜만에 대딩친구들 다 만났다\n오랜만에 만난 지영이랑 원래 잘 만나는 지은이민정이...
# 1           4     연경 연희점                                          .\n오늘은 신촌
# 2           4     연경 연희점  #신촌 에서 토요일날 #마마무 도 보고 개이득!\n근데 멀리서 줌 땡겨가지고 화질은...
# 3           4     연경 연희점  #보통술집 #마지막\n하루키, 원부술집에 이어 이렇게 또 이별을\n전, 현직원 거의...
# 4           4     연경 연희점  얼마부터 배달되냐 여쭤봤더니 동네니까 해드릴게여 라며 ㅇㅋ 해주신 사장님 감사해요\...
# 5           4     연경 연희점  사나흘 집밥 열심히 해먹었더니 이제 지겹다ㅠ\n역시 난 배달음식 ㅋㅋ\n24시라 별...
# 6           4     연경 연희점  .\n신촌에서 먹은 #삼선짬뽕 🍤🍜\n여기 정말 맛있다! 숨은 #맛집 (카메라로 찍...
# 7           4     연경 연희점  #신촌연경 #불짜장 #탕수육\n불짜장은 맛있기는 한데.. 진짜 맵다...\n다음에 ...
# 8           4     연경 연희점  #첫줄빠이\n지금시간 #am1시 집근처에서 해장의시간\n#굴짬뽕 #사천짜장 🔥🔥🔥😡...
# 9           4     연경 연희점  크림새우 와 쟁반짜장.\n_\n#신촌 #연경 #신촌연경 #크림새우 #쟁반짜장 #존맛...
# 10          4     연경 연희점      요즘 내 주말점심메이트 #신촌 #연경24시 #신촌연경 #잡탕밥 #중식 #먹스타그램
# 11          4     연경 연희점  연경 간짜장면. 짜장면을 한동안 너무 많이 먹어서 한 입에 주방장 혈액형을 맞출 수...
# 12          4     연경 연희점  신촌 연경의 난자완스. 드디어 탕수육 위에 적힌 메뉴를 주문할 수 있는 나이가 되었...
# 13          4     연경 연희점  쉬바펍에서 신촌연경의 탕수육을 주문. 12시 이후에 먹는 음식은 그 날의 첫 끼라서...
# 14          4     연경 연희점  신촌 연경의 라조육. 탕수육이라고 하면 그런줄 알고 먹었을.\n\n#연경 #신촌연경...
# 15          4     연경 연희점  어머니는 짜장면이 싫다고 하셨어. 대신 짬뽕이 좋다고 하셨어.\n\n#짜장면 #중국...
# 16          4     연경 연희점  특별한 날이 아닌데 탕수육을 먹으면 비로소 내가 어른이 되었다고 느낀다. 어른의 씀...
# 17          4     연경 연희점  배달대신 가서 먹었더니 양이 딱 두 배.\n\n#연경 #신촌연경 #24시 #짬짜면 ...
# 18          4     연경 연희점  탕수육 정식. 다른 곳보다 1,000원 싼게 메리트.\n\n#신촌 #연대 #연세대 ...
# 19          4     연경 연희점  볶음짬뽕 널 왜 이제야 만난거니.\n\n#신촌 #연대 #연세대 #이대 #이화여대 #...
# 20          4     연경 연희점  탕수육은 먹다보면 금새 질리는데, 반가운 손님이 몇일째 돌아가지 않는 그런 기분.\...
# 21          4     연경 연희점  오늘 간짜장은 주방장이 혼신의 힘을 다한것 같아 만족스럽다. 고기가 많았음.\n\n...
# 22          4     연경 연희점  오늘 나온 탕수육은 신선하고 따뜻했다. 주방장의 기합소리가 귀에 선명히 들리는 듯했...
# 23          4     연경 연희점  일요일이 아니라 짜파게티 요리사가 되지 못해 간짜장을 주문했다.\n\n#신촌 #연대...
# 24         20    연희김밥 본점  매워서 진짜 뒈질것같은데\n계속 집어먹게되는 마성의 김밥\n.\n.\n.\n.\n....
# 25         20    연희김밥 본점  오징어김밥이 유명한 연희김밥🍙\n매운양념으로 버무린 반건조 오징어가 들어간 김밥인데...
# 26         20    연희김밥 본점            #연희김밥 #김밥맛집 🍙\n#체인점 #신촌연희김밥 #신촌맛집 #신촌김밥
# 27         20    연희김밥 본점  🍙와사비 참치 김밥, 오징어 김밥🍙\n\n#신촌맛집 #신촌연희김밥 #연희김밥 #김밥...
# 28         20    연희김밥 본점  오빠 우리 오디가~~~??🤪\n\n오늘은 곽쥰구낙쓰와 힐링여행,\n내일은 라이브방송...
# 29         20    연희김밥 본점  .\n일요일 저녁은 애정하는 연희김밥 :).\n신메뉴 와사비 참치김밥과 늘먹던 참치...
# 30         20    연희김밥 본점  요새 맛있는 김밥 먹고 싶었는데, 일하는 곳 근처에 이렇게 괜찮은 곳이! 청양고추 ...
# 31         20    연희김밥 본점  코리아요리아트아카데미홍대점 #요리학원 #홍대요리학원 #일상 #일상스타그램 #소통 #...
# 32         20    연희김밥 본점                   #키친봄날 #참치김밥#신촌연희김밥 #오징어꼬마김밥 #맛있당
# 33         23         책바  .\n<오늘도 우리는 살아간다: 서대문구 마포구에서>\n\n다섯 번째 동반매장을 소...
# 34         23         책바  <오늘도우리는살아간다: 서대문구/마포구에서>\n동반매장을 소개합니다 _ 5\n___...
# 35         25     효동각 본점                             #병원왔다가 #신촌효동각 #맛난짜장면흡입
# 36         25     효동각 본점  #짜장면 #자장면 #효동각 #신촌효동각 #곱배기 #먹스타그램 #일상\n집근처에 이런...
# 37         25     효동각 본점  오늘의점심 ♡ 자장면!!!!! 하루에 세시간만 문여는 효동각 ♡ 중간중간 씹히는 버...
# 38         25     효동각 본점  .\n혼자서 곱배기 다 먹었어!!!😣😣😭😭😭\n.\n건강한맛 좋아좋아😋😋😋\n.\n...
# 39         25     효동각 본점  짜장면 맛집 효동각\n♡\n♡\n빈그릇을 부르는 줄서서 먹는 짜장면\n맛있어ㆍ오늘은...
# 40         25     효동각 본점  #신촌세브란스맛집\n#신촌세브란스치과병원\n#이대후문맛집\n#세브란스치과병원\n#신...
# 41         25     효동각 본점             외국인이 보면 놀라겠다. 자장면에 갈매기가 들어간다니.. #신촌효동각
# 42         25     효동각 본점  #효동각 #신촌효동각#신촌세브란스병원효동각\n신촌 세브란스병원 외진곳에 있는 효동각...
# 43         25     효동각 본점                          #맛스타그램 #먹스타그램 #신촌효동각 #자장면
# 44         25     효동각 본점  🐷 신촌 맛집 25. #효동각\n\n연세대학교 동문 근처 중국집!\n\n자장면 단일...
# 45         25     효동각 본점  신촌 효동각~옛날짜장~짜장하나만 판매한다. 너무 맛나는 효동각~!\n#신촌효동각 #...
# 46         25     효동각 본점  짜장면에서 느끼는 건강한 맛 ㅋㅋㅋ\n\n#백종원3대천왕짜장 #신촌효동각 #완짜 #...
# 47         26    식탁 하늬솔점  아들이 좋아하는\n#바질페이토파스타\n즐겨먹던 #신촌식탁 엘 못가\n오랜만에 만들어...
# 48         26    식탁 하늬솔점  🙇‍♀️\n나를 가장 나답게 만들어주는 사람들과 함께할 수 있어서\n감사합니다. (...
# 49         26    식탁 하늬솔점  .\n▶ #SICTAC (식탁)\n▶ #이대후문맛집 #에그인헬\n.\n이런 헬이라면...
#
#    source
# 0   인스타그램
# 1   인스타그램
# 2   인스타그램
# 3   인스타그램
# 4   인스타그램
# 5   인스타그램
# 6   인스타그램
# 7   인스타그램
# 8   인스타그램
# 9   인스타그램
# 10  인스타그램
# 11  인스타그램
# 12  인스타그램
# 13  인스타그램
# 14  인스타그램
# 15  인스타그램
# 16  인스타그램
# 17  인스타그램
# 18  인스타그램
# 19  인스타그램
# 20  인스타그램
# 21  인스타그램
# 22  인스타그램
# 23  인스타그램
# 24  인스타그램
# 25  인스타그램
# 26  인스타그램
# 27  인스타그램
# 28  인스타그램
# 29  인스타그램
# 30  인스타그램
# 31  인스타그램
# 32  인스타그램
# 33  인스타그램
# 34  인스타그램
# 35  인스타그램
# 36  인스타그램
# 37  인스타그램
# 38  인스타그램
# 39  인스타그램
# 40  인스타그램
# 41  인스타그램
# 42  인스타그램
# 43  인스타그램
# 44  인스타그램
# 45  인스타그램
# 46  인스타그램
# 47  인스타그램
# 48  인스타그램
# 49  인스타그램

# %%
def preprocessing_2(review):
    total_sentence = ""
    for sentence in kkma.sentences(review):
        sentence = re.sub('([a-zA-Z])','',sentence)
        sentence = re.sub('[ㄱ-ㅎㅏ-ㅣ]+','',sentence)
        sentence = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','',sentence)
        if len(sentence) == 0:
            continue
        if len(sentence) < 198:
            sentence = spacing(sentence)
        sentence += '. '
        total_sentence += sentence
    return total_sentence

# %%
def make_review_list(df):
    total_list = []
    for i in range(len(df)):
        total_list.append(preprocessing_2(df.iloc[i].review))
        
    return total_list

# %%
def preprocessing(review):
    total_review = ''
    #인풋리뷰
    for idx in range(len(review)):
        r = review[idx]
        #하나의 리뷰에서 문장 단위로 자르기
        for sentence in kkma.sentences(r):
            sentence = re.sub('([a-zA-Z])','',sentence)
            sentence = re.sub('[ㄱ-ㅎㅏ-ㅣ]+','',sentence)
            sentence = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','',sentence)
            if len(sentence) == 0:
                continue
            if len(sentence) < 198:
                sentence = spacing(sentence)
            sentence += '. '
            total_review += sentence
    return total_review

# %%
new_df = tf[tf['dining_id'] == 25]

# %%
service_good_feature = {'서비스':['좋','친절','괜찮','최고','빠르','짱','훌륭','추천','감사','구수','최상','대박',
                               '훈훈','특별','개이득','최고','만족','세련','최고','감동'],
                        '사장':['친절','스윗','센스'],
                        '알바':['친절','스윗','센스'],
                        '직원': ['친절','스윗','센스'],
                        '일을':['잘','빠르게'],
                        '일도':['잘','빠르게'],
                        '서빙':['잘','빠르게']}

service_bad_feature = {'서비스': ['아쉽','최악','나쁘','느리','빡치','비추','별로','그냥','낙제','쏘다쏘다','엉망','실망','불친절','문제','컴플레인',
                               '거지','그닥','그다지','구려','불편','엉성','헬','개판'],
                       '알바':['불친절','똑바로','재수'],
                       '사장':['불친절','똑바로','재수'],
                       '직원':['불친절','똑바로','재수'],
                      '일을':['못','느리게','답답'],
                      '일도':['못','느리게', '천천히'],
                      '서빙':['못','느리게','천천히','답답']}

taste_good_feature = {'간':['맞','적절','딱','환상','담백'],
                      '음식':['깔끔'],
                      '맛':['있','좋','나다','최고']}

taste_bad_feature = {'간':['세','쎄','강하다','별로'],
                     '음식':['별로','쏘다쏘다','최악'],
                     '맛':['별로','최악']}

taste_good_emotion = ['고소','부드럽','신선','촉촉','싱싱','정갈','최고']

taste_bad_emotion = ['싱겁','느끼다하다','짜다','느끼다','짜다','딱딱하다','차갑다']

cost_good_feature = {'가격': ['괜찮','착하다','저렴','적당','싸다','좋다','합리적','훌륭','최고','만족','마음','든든','알맞다',
                            '무난','괜춘','최상','최상','굿','엄지','낮'],
                     '가성비':['괜찮','착하다','저렴','적당','싸다','좋다','합리적','훌륭','최고','만족','마음','든든','알맞다',
                            '무난','괜춘','최상','최상','굿','엄지'],
                     '양':['많','적당','푸짐하고','괜찮다','넉넉','충분','든든']
                     }

cost_bad_feature ={'가격': ['비싸','있다','나쁘','사악','비효율','높다','부담','아쉽','쏘다쏘다','별로','그닥','그다지','쎄','ㅎㄷㄷ','높','거품'],
                   '가성비':['별로'],
                   '양':['적다','작다','아쉽','적다','다소','별로'],
                   }

atmosphere_good_feature = {'분위기': ['좋','괜찮','조용','깔끔','적당','깡패','굉장','아담','완벽','아기자기','고급','최고','세련','만족','아늑','훌륭','예쁘','이쁘','짱',
                                   '심쿵','따뜻','깨끗','독특','매력','모던','취향저격','맘','마음','클래식','아름','인상적','귀엽','포근'], 
                           '인테리어': ['좋','괜찮','조용','깔끔','적당','깡패','굉장','아담','완벽','아기자기','고급','최고','세련','만족','아늑','훌륭','예쁘','이쁘','짱',
                                    '심쿵','따뜻','깨끗','독특','매력','모던','취향저격','맘','마음','클래식','아름','인상적','귀엽','포근']}

atmosphere_bad_feature = {'분위기': ['나쁘다','바쁘다','어수선하다','이상하다','촌스럽다','별로','부담스럽다','시끄럽','복잡' ],
                          '인테리어':[]}

visit_good_feature = {'의사':['있다','충만','백프로','백프롭','많','만땅','마구','그득','만점','넘침'],
                      '다시':['가다','오다','방문','찾다','가보다','한번','갈다','찾아가다','가야지','갈거다','방문하다보고',
                            '생각나다','방문한다면','와보고','재방문','접하다','간다면','갈다때가','먹다고프다','방문한다임','오자고','가기로','갈다생각이다','가면'],
                      '굳이':[]}

visit_bad_feature = {'의사':['글쎄'],
                     '굳이':['다시','많이','여기까지','줄서서','찾아','시키다','가다','찾다','여기','기다리다','줄을','사먹'],
                     '다시':[]}

negative_word_emotion = ['안','않','못','없','아닌','아니']

# %%
def get_feature_keywords(feature_keywords, review):
    feature_temp = []
    for keyword in feature_keywords:
        if re.findall(keyword, review):
            sub_list = ['게','고','음','며','데','만','도','면']
            
            for sub in sub_list:
                if sub+' ' in review:
                    review = re.sub(sub+' ', sub+',', review)
                
            a = re.findall(keyword +'+[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+\s+[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+\s+[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+',review) # K한 한 한글
            b = re.findall(keyword + '+\s+[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+\s+[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+',review) # K 한 한글 
            c = re.findall('[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+\s+' + keyword +'[ㄱ-ㅎ|ㅏ-ㅣ|가-힣]+',review) # 한 K한글 예쁜 분위기가
                
            for ngram in a:
                t = ()
                feature_temp.append(t + (ngram,keyword))
            for ngram in b:
                t = ()
                feature_temp.append(t + (ngram,keyword))
            for ngram in c:
                t = ()
                feature_temp.append(t + (ngram,keyword))
                
    return feature_temp

# %%
def get_feature_emotions(feature_good_dict,feature_bad_dict, feature_temp):
    good_feature_emotion_list = []
    bad_feature_emotion_list = []
    
    for ngrams in feature_temp:
        keyword = ngrams[1]
        ngram = ngrams[0]
        is_bad_feature = None
        
        good_emotion_list = feature_good_dict[keyword]
        bad_emotion_list = feature_bad_dict[keyword]
        for emotion in good_emotion_list:
            if re.findall(emotion, ngram):
                is_bad_feature = False  
        for emotion in bad_emotion_list:
            if re.findall(emotion, ngram):
                is_bad_feature = True    
        for negative in negative_word_emotion:
            if re.findall(negative, ngram):
                if is_bad_feature == True:
                    is_bad_feature = False
                    break
                elif is_bad_feature == False:
                    is_bad_feature = True
                    break
                else:
                    is_bad_feature = True
                    break   
        if is_bad_feature:
            bad_feature_emotion_list.append(ngram)
        elif is_bad_feature == False:
            good_feature_emotion_list.append(ngram)
        else:
            pass
    return good_feature_emotion_list, bad_feature_emotion_list

# %%
def get_taste_emotion(taste_good_emotions, taste_bad_emotions):
    bad_taste_emotion_list = []
    good_taste_emotion_list = []
    for ngrams in taste_good_emotions:
        ngram = ngrams[0]
        is_bad_taste = False
        for negative in negative_word_emotion:
            if re.findall(negative,ngram):
                is_bad_taste = True
        if is_bad_taste:
            bad_taste_emotion_list.append(ngram)
        else:
            good_taste_emotion_list.append(ngram)
    
    for ngrams in taste_bad_emotions:
        ngram = ngrams[0]
        is_bad_taste = True
        for negative in negative_word_emotion:
            if re.findall(negative,ngram):
                is_bad_taste = False
        if is_bad_taste:
            bad_taste_emotion_list.append(ngram)
        else:
            good_taste_emotion_list.append(ngram)
            
    return good_taste_emotion_list, bad_taste_emotion_list

# %%
service_temp = get_feature_keywords(service_good_feature.keys(), review)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3f05cf402146> in <module>
# ----> 1 service_temp = get_feature_keywords(service_good_feature.keys(), review)
#
# NameError: name 'review' is not defined

# %%
get_feature_emotions(service_good_feature, service_bad_feature, service_temp)
# Out:
# (['직원분들은 친절하셔서 좋았어요'], [])

# %% [markdown]
# # 리뷰 하나 테스트

# %%
service_temp = get_feature_keywords(service_good_feature.keys(), review)
good_service,bad_service = get_feature_emotions(service_good_feature, service_bad_feature, service_temp)

atmosphere_temp = get_feature_keywords(atmosphere_good_feature.keys(), review)
good_atmosphere,bad_atmosphere = get_feature_emotions(atmosphere_good_feature, atmosphere_bad_feature, atmosphere_temp)
    
cost_temp = get_feature_keywords(cost_good_feature.keys(), review)
good_cost,bad_cost = get_feature_emotions(cost_good_feature, cost_bad_feature, cost_temp)
    
visit_temp = get_feature_keywords(visit_good_feature.keys(), review)
good_visit,bad_visit = get_feature_emotions(visit_good_feature, visit_bad_feature, visit_temp)
    
taste_temp = get_feature_keywords(taste_good_feature.keys(), review)
good_taste,bad_taste = get_feature_emotions(taste_good_feature, taste_bad_feature, taste_temp)
taste_good_emotion_temp = get_feature_keywords(taste_good_emotion, review)
taste_bad_emotion_temp = get_feature_keywords(taste_bad_emotion, review)
good_taste2, bad_taste2 = get_taste_emotion(taste_good_emotion_temp,taste_bad_emotion_temp)
good_taste.extend(good_taste2)
bad_taste.extend(bad_taste2)


print('good service emotions :{}'.format(len(good_service)))
for ngram in good_service:
    print(ngram)
print('bad service emotions :{}'.format(len(bad_service)))
for ngram in bad_service:
    print(ngram)
print('good atmosphere emotions :{}'.format(len(good_atmosphere)))
for ngram in good_atmosphere:
    print(ngram)
print('bad atmosphere emotions :{}'.format(len(bad_atmosphere)))
for ngram in bad_atmosphere:
    print(ngram)
print('good cost emotions :{}'.format(len(good_cost)))
for ngram in good_cost:
    print(ngram)
print('bad cost emotions :{}'.format(len(bad_cost)))
for ngram in bad_cost:
    print(ngram)
print('good visit emotions :{}'.format(len(good_visit)))
for ngram in good_visit:
    print(ngram)
print('bad visit emotions :{}'.format(len(bad_visit)))
for ngram in bad_visit:
    print(ngram)
print('good taste emotions :{}'.format(len(good_taste)))
for ngram in good_taste:
    print(ngram)
print('bad taste emotions :{}'.format(len(bad_taste)))
for ngram in bad_taste:
    print(ngram)
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-9301080be276> in <module>
# ----> 1 service_temp = get_feature_keywords(service_good_feature.keys(), review)
#       2 good_service,bad_service = get_feature_emotions(service_good_feature, service_bad_feature, service_temp)
#       3
#       4 atmosphere_temp = get_feature_keywords(atmosphere_good_feature.keys(), review)
#       5 good_atmosphere,bad_atmosphere = get_feature_emotions(atmosphere_good_feature, atmosphere_bad_feature, atmosphere_temp)
#
# NameError: name 'review' is not defined

# %%
restaurant_good_service_count = 0
restaurant_bad_service_count = 0
restaurant_good_atmosphere_count =0
restaurant_bad_atmosphere_count =0
restaurant_good_cost_count =0
restaurant_bad_cost_count =0
restaurant_good_visit_count = 0
restaurant_bad_visit_count = 0
restaurant_good_taste_count = 0
restaurant_bad_taste_count = 0

reviews_list = make_review_list(new_df)
for j, review in enumerate(reviews_list):
    #print review
    service_temp = get_feature_keywords(service_good_feature.keys(), review)
    good_service,bad_service = get_feature_emotions(service_good_feature, service_bad_feature, service_temp)

    atmosphere_temp = get_feature_keywords(atmosphere_good_feature.keys(), review)
    good_atmosphere,bad_atmosphere = get_feature_emotions(atmosphere_good_feature, atmosphere_bad_feature, atmosphere_temp)

    cost_temp = get_feature_keywords(cost_good_feature.keys(), review)
    good_cost,bad_cost = get_feature_emotions(cost_good_feature, cost_bad_feature, cost_temp)

    visit_temp = get_feature_keywords(visit_good_feature.keys(), review)
    good_visit,bad_visit = get_feature_emotions(visit_good_feature, visit_bad_feature, visit_temp)

    taste_temp = get_feature_keywords(taste_good_feature.keys(), review)
    good_taste,bad_taste = get_feature_emotions(taste_good_feature, taste_bad_feature, taste_temp)
    taste_good_emotion_temp = get_feature_keywords(taste_good_emotion, review)
    taste_bad_emotion_temp = get_feature_keywords(taste_bad_emotion, review)
    good_taste2, bad_taste2 = get_taste_emotion(taste_good_emotion_temp,taste_bad_emotion_temp)
    good_taste.extend(good_taste2)
    bad_taste.extend(bad_taste2)

    if len(good_service) > len(bad_service):
        restaurant_good_service_count += 1
    elif len(good_service) < len(bad_service):
        restaurant_bad_service_count += 1
    else:
        pass
        
    if len(good_atmosphere) > len(bad_atmosphere):
        restaurant_good_atmosphere_count += 1
    elif len(good_atmosphere) < len(bad_atmosphere):
        restaurant_bad_atmosphere_count += 1
    else:
        pass
        
    if len(good_cost) > len(bad_cost):
        restaurant_good_cost_count += 1
    elif len(good_cost) < len(bad_cost):
        restaurant_bad_cost_count += 1
    else:
        pass
            
    if len(good_visit) > len(bad_visit):
        restaurant_good_visit_count += 1
    elif len(good_visit) < len(bad_visit):
        restaurant_bad_visit_count += 1
    else:
        pass
        
    if len(good_taste) > len(bad_taste):
        restaurant_good_taste_count += 1
    elif len(good_taste) < len(bad_taste):
        restaurant_bad_taste_count += 1
    else:
        pass
    
print('Total review count: {}'.format(len(reviews_list)))
print('Good service: {}/{} = {}'.format(restaurant_good_service_count,restaurant_good_service_count + restaurant_bad_service_count,check_division(restaurant_good_service_count, restaurant_good_service_count + restaurant_bad_service_count)))
print('Bad service: {}/{} = {}'.format(restaurant_bad_service_count,restaurant_good_service_count + restaurant_bad_service_count, check_division(restaurant_bad_service_count, restaurant_good_service_count + restaurant_bad_service_count)))
print('Good atmosphere: {}/{} = {}'.format(restaurant_good_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count,check_division(restaurant_good_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count))) 
print('Bad atmosphere: {}/{} = {}'.format(restaurant_bad_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count, check_division(restaurant_bad_atmosphere_count ,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count)))
print('Good cost: {}/{} = {}'.format(restaurant_good_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count, check_division(restaurant_good_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count)))
print('Bad cost: {}/{} = {}'.format(restaurant_bad_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count, check_division(restaurant_bad_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count)))
print('Good taste: {}/{} = {}'.format(restaurant_good_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count,check_division(restaurant_good_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count)))
print('Bad taste: {}/{} = {}'.format(restaurant_bad_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count,check_division(restaurant_bad_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count)))
print()
# Out:
# Total review count: 12
# Good service: 0/0 = 0
# Bad service: 0/0 = 0
# Good atmosphere: 0/0 = 0
# Bad atmosphere: 0/0 = 0
# Good cost: 0/0 = 0
# Bad cost: 0/0 = 0
# Good taste: 3/4 = 0.75
# Bad taste: 1/4 = 0.25

# %%
check_division = lambda x, y: y if y ==0 else round((x / float(y)),2)

for i, reviews in enumerate(seoul_restaurant_reviews[:30]):
    restaurant_good_service_count = 0
    restaurant_bad_service_count = 0
    restaurant_good_atmosphere_count =0
    restaurant_bad_atmosphere_count =0
    restaurant_good_cost_count =0
    restaurant_bad_cost_count =0
    restaurant_good_visit_count = 0
    restaurant_bad_visit_count = 0
    restaurant_good_taste_count = 0
    restaurant_bad_taste_count = 0
    
    reviews_list = do_stemming(reviews['review'])
    for j, review in enumerate(reviews_list):
        #print review
        service_temp = get_feature_keywords(service_good_feature.keys(), review)
        good_service,bad_service = get_feature_emotions(service_good_feature, service_bad_feature, service_temp)

        atmosphere_temp = get_feature_keywords(atmosphere_good_feature.keys(), review)
        good_atmosphere,bad_atmosphere = get_feature_emotions(atmosphere_good_feature, atmosphere_bad_feature, atmosphere_temp)

        cost_temp = get_feature_keywords(cost_good_feature.keys(), review)
        good_cost,bad_cost = get_feature_emotions(cost_good_feature, cost_bad_feature, cost_temp)

        visit_temp = get_feature_keywords(visit_good_feature.keys(), review)
        good_visit,bad_visit = get_feature_emotions(visit_good_feature, visit_bad_feature, visit_temp)

        taste_temp = get_feature_keywords(taste_good_feature.keys(), review)
        good_taste,bad_taste = get_feature_emotions(taste_good_feature, taste_bad_feature, taste_temp)
        taste_good_emotion_temp = get_feature_keywords(taste_good_emotion, review)
        taste_bad_emotion_temp = get_feature_keywords(taste_bad_emotion, review)
        good_taste2, bad_taste2 = get_taste_emotion(taste_good_emotion_temp,taste_bad_emotion_temp)
        good_taste.extend(good_taste2)
        bad_taste.extend(bad_taste2)

        if len(good_service) > len(bad_service):
            restaurant_good_service_count += 1
        elif len(good_service) < len(bad_service):
            restaurant_bad_service_count += 1
        else:
            pass
        
        if len(good_atmosphere) > len(bad_atmosphere):
            restaurant_good_atmosphere_count += 1
        elif len(good_atmosphere) < len(bad_atmosphere):
            restaurant_bad_atmosphere_count += 1
        else:
            pass
        
        if len(good_cost) > len(bad_cost):
            restaurant_good_cost_count += 1
        elif len(good_cost) < len(bad_cost):
            restaurant_bad_cost_count += 1
        else:
            pass
            
        if len(good_visit) > len(bad_visit):
            restaurant_good_visit_count += 1
        elif len(good_visit) < len(bad_visit):
            restaurant_bad_visit_count += 1
        else:
            pass
        
        if len(good_taste) > len(bad_taste):
            restaurant_good_taste_count += 1
        elif len(good_taste) < len(bad_taste):
            restaurant_bad_taste_count += 1
        else:
            pass
    
    print('Total review count: {}'.format(len(reviews_list)))
    print('Good service: {}/{} = {}'.format(restaurant_good_service_count,restaurant_good_service_count + restaurant_bad_service_count,check_division(restaurant_good_service_count, restaurant_good_service_count + restaurant_bad_service_count)))
    print('Bad service: {}/{} = {}'.format(restaurant_bad_service_count,restaurant_good_service_count + restaurant_bad_service_count, check_division(restaurant_bad_service_count, restaurant_good_service_count + restaurant_bad_service_count)))
    print('Good atmosphere: {}/{} = {}'.format(restaurant_good_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count,check_division(restaurant_good_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count))) 
    print('Bad atmosphere: {}/{} = {}'.format(restaurant_bad_atmosphere_count,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count, check_division(restaurant_bad_atmosphere_count ,restaurant_good_atmosphere_count + restaurant_bad_atmosphere_count)))
    print('Good cost: {}/{} = {}'.format(restaurant_good_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count, check_division(restaurant_good_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count)))
    print('Bad cost: {}/{} = {}'.format(restaurant_bad_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count, check_division(restaurant_bad_cost_count,restaurant_good_cost_count + restaurant_bad_cost_count)))
    print('Good taste: {}/{} = {}'.format(restaurant_good_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count,check_division(restaurant_good_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count)))
    print('Bad taste: {}/{} = {}'.format(restaurant_bad_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count,check_division(restaurant_bad_taste_count,restaurant_good_taste_count + restaurant_bad_taste_count)))
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-35ba5349e9bc> in <module>
#       1 check_division = lambda x, y: y if y ==0 else round((x / float(y)),2)
#       2
# ----> 3 for i, reviews in enumerate(seoul_restaurant_reviews[:30]):
#       4     restaurant_good_service_count = 0
#       5     restaurant_bad_service_count = 0
#
# NameError: name 'seoul_restaurant_reviews' is not defined
